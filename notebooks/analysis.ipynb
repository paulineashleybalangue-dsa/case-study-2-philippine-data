# %%
from pathlib import Path
import sys

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Allow the notebook to import modules from the project root.
sys.path.append("..")

from config import CONFIG, REQUIRED_COLUMNS
from src.data_processing import (
    load_csv_chunks,
    prepare_chunk,
)
from src.analysis import CustomsAnalyzer
from src.numpy_analysis import run_numpy_comparison
from src.visualization import (
    create_bar_plot,
    create_heatmap,
)
from src.validation import (
    inspect_raw_data,
    inspect_dataset,
    create_validation_results,
    calculate_file_sha256,
)

# %%
chunks = load_csv_chunks(
    CONFIG["input_path"],
    REQUIRED_COLUMNS,
    CONFIG["chunksize"],
)

first_chunk = next(chunks)

print("First chunk rows:", len(first_chunk))
print("Columns:")
print(first_chunk.columns.tolist())
# Out:
# First chunk rows: 100000
# Columns:
# ['tq', 'dutiablevaluephp', 'countryorigin_iso3']

# %%
inspection = inspect_dataset(
    CONFIG["input_path"],
    CONFIG["chunksize"],
)

inspection
# Out:
#                   column    dtype  missing_count
# 0                    uid      str              0
# 1                     ty    int64              0
# 2                     tq      str              0
# 3                     tm      str              0
# 4                  entry      str         124105
# 5                 hscode    int64              0
# 6       goodsdescription      str           4389
# 7                      p  float64              0
# 8                      q  float64              0
# 9                  m_fob  float64              0
# 10                 m_cif  float64              0
# 11                fx_usd  float64              0
# 12  dutiablevalueforeign  float64              0
# 13          exchangerate  float64              0
# 14              currency      str              0
# 15      dutiablevaluephp    int64              0
# 16              dutypaid    int64              0
# 17       exciseadvalorem  float64        1258038
# 18              arrastre  float64        2236612
# 19              wharfage  float64        2236612
# 20               vatbase    int64              0
# 21               vatpaid    int64              0
# 22              othertax  float64        1275491
# 23     finesandpenalties  float64        1258583
# 24           dutiestaxes    int64              0
# 25              prefcode      str        1963535
# 26    countryorigin_iso3      str              0
# 27    countryexport_iso3      str              0
# 28               subport      str         124101
# 29                  port      str         124101

# %%
raw_stats = inspect_raw_data(
    CONFIG["input_path"],
    CONFIG["chunksize"],
)

raw_stats
# Out:
# {'raw_rows': 2236612,
#  'raw_sum': 3587267375257.0,
#  'selected_sum': 3587267375257.0,
#  'missing_measure': 0,
#  'selected_rows': 2236612,
#  'excluded_rows': 0}

# %%
analyzer = CustomsAnalyzer(
    output_dir=CONFIG["output_dir"],
    group_columns=CONFIG["group_columns"],
    measure_column=CONFIG["measure_column"],
)

chunks = load_csv_chunks(
    CONFIG["input_path"],
    REQUIRED_COLUMNS,
    CONFIG["chunksize"],
)

for chunk in chunks:
    selected = prepare_chunk(
        chunk,
        CONFIG["minimum_dutiable_value_php"],
        CONFIG["high_value_threshold_million_php"],
    )

    analyzer.add_chunk(
        selected,
        len(chunk),
        len(selected),
    )

data = analyzer.combine_chunks()

print("Selected rows:", len(data))
print()
print(data.head())
# Out:
# Selected rows: 2236612
#
#        tq  dutiablevaluephp countryorigin_iso3  dutiablevalue_million_php  \
# 0  2015q1          90088007                MYS                  90.088007
# 1  2015q1          15742304                CHN                  15.742304
# 2  2015q1          52605886                CHN                  52.605886
# 3  2015q1          34181694                CHN                  34.181694
# 4  2015q1           7522344                KOR                   7.522344
#
#   value_band
# 0   Standard
# 1   Standard
# 2   Standard
# 3   Standard
# 4   Standard

# %%
data.loc[
    (
        data["tq"].notna()
        & (data["dutiablevaluephp"] > 0)
    ),
    [
        "tq",
        "countryorigin_iso3",
        "dutiablevaluephp",
        "dutiablevalue_million_php",
        "value_band",
    ],
].head(10)
# Out:
#        tq countryorigin_iso3  dutiablevaluephp  dutiablevalue_million_php  \
# 0  2015q1                MYS          90088007                  90.088007
# 1  2015q1                CHN          15742304                  15.742304
# 2  2015q1                CHN          52605886                  52.605886
# 3  2015q1                CHN          34181694                  34.181694
# 4  2015q1                KOR           7522344                   7.522344
# 5  2015q1                KOR            937401                   0.937401
# 6  2015q1                KOR            454267                   0.454267
# 7  2015q1                KOR            437421                   0.437421
# 8  2015q1                CHN           9536863                   9.536863
# 9  2015q1                CHN         123198882                 123.198882
#
#   value_band
# 0   Standard
# 1   Standard
# 2   Standard
# 3   Standard
# 4   Standard
# 5   Standard
# 6   Standard
# 7   Standard
# 8   Standard
# 9       High

# %%
grouped = analyzer.create_grouped_summary(data)

grouped.head(10)
# Out:
#   countryorigin_iso3  row_count  valid_measure_count  measure_sum  \
# 0                AFG          5                    5       588546
# 1                AGO          4                    4     11752842
# 2                AIA         26                   26      6120010
# 3                ALB         33                   33      4355770
# 4                AND          8                    8     16228840
# 5                ANT         81                   81    393863146
# 6                ARE       2851                 2851  29645763789
# 7                ARG       1089                 1089  13213323494
# 8                ARM          5                    5       998542
# 9                ASM         14                   14      2575220
#
#    measure_mean
# 0  1.177092e+05
# 1  2.938210e+06
# 2  2.353850e+05
# 3  1.319930e+05
# 4  2.028605e+06
# 5  4.862508e+06
# 6  1.039837e+07
# 7  1.213345e+07
# 8  1.997084e+05
# 9  1.839443e+05

# %%
print("Number of country groups:", len(grouped))
print("Total grouped rows:", grouped["row_count"].sum())
print("Total grouped measure:", grouped["measure_sum"].sum())
# Out:
# Number of country groups: 197
# Total grouped rows: 2236612
# Total grouped measure: 3587267375257

# %%
grouped.to_csv(
    CONFIG["output_dir"] / "grouped.csv",
    index=False,
)

print("grouped.csv saved.")
# Out:
# grouped.csv saved.

# %%
grouped_two = analyzer.create_two_category_summary(data)

grouped_two.head(10)
# Out:
#   countryorigin_iso3      tq  row_count  measure_sum
# 0                AFG  2015q3          3       567713
# 1                AFG  2015q4          2        20833
# 2                AGO  2015q3          4     11752842
# 3                AIA  2015q3          9      1429763
# 4                AIA  2015q4         17      4690247
# 5                ALB  2015q2          1       138212
# 6                ALB  2015q3         16       947695
# 7                ALB  2015q4         16      3269863
# 8                AND  2015q2          3      1551437
# 9                AND  2015q3          3      4748724

# %%
print("Number of country-quarter groups:", len(grouped_two))
print("Total grouped rows:", grouped_two["row_count"].sum())
print("Total grouped measure:", grouped_two["measure_sum"].sum())
# Out:
# Number of country-quarter groups: 628
# Total grouped rows: 2236612
# Total grouped measure: 3587267375257

# %%
grouped_two.to_csv(
    CONFIG["output_dir"] / "grouped_two.csv",
    index=False,
)

print("grouped_two.csv saved.")
# Out:
# grouped_two.csv saved.

# %%
pivot = analyzer.create_pivot(grouped_two)

pivot.head(10)
# Out:
# tq countryorigin_iso3        2015q1        2015q2        2015q3        2015q4  \
# 0                 AFG           NaN           NaN  5.677130e+05  2.083300e+04
# 1                 AGO           NaN           NaN  1.175284e+07           NaN
# 2                 AIA           NaN           NaN  1.429763e+06  4.690247e+06
# 3                 ALB           NaN  1.382120e+05  9.476950e+05  3.269863e+06
# 4                 AND           NaN  1.551437e+06  4.748724e+06  9.928679e+06
# 5                 ANT  4.093564e+07  3.245682e+07  2.156041e+08  1.048666e+08
# 6                 ARE  1.143155e+10  5.646697e+09  8.342975e+09  4.224541e+09
# 7                 ARG  2.034266e+09  8.810729e+08  3.759537e+09  6.538448e+09
# 8                 ARM           NaN           NaN  2.677720e+05  7.307700e+05
# 9                 ASM  3.325130e+05           NaN  6.254110e+05  1.617296e+06
#
# tq        Total
# 0        588546
# 1      11752842
# 2       6120010
# 3       4355770
# 4      16228840
# 5     393863146
# 6   29645763789
# 7   13213323494
# 8        998542
# 9       2575220

# %%
print("Pivot grand total:", pivot.loc[pivot["countryorigin_iso3"] == "Total", "Total"].iloc[0])
# Out:
# Pivot grand total: 3587267375257

# %%
pivot.to_csv(
    CONFIG["output_dir"] / "pivot.csv",
    index=False,
)

print("pivot.csv saved.")
# Out:
# pivot.csv saved.

# %%
top10 = analyzer.create_top10(grouped)

top10
# Out:
#   countryorigin_iso3  row_count  valid_measure_count   measure_sum  \
# 0                CHN     589626               589626  651605135422
# 1                JPN     352375               352375  304562507423
# 2                USA     209259               209259  291521135474
# 3                KOR     112063               112063  266807274024
# 4                THA      86863                86863  252139451874
# 5                TWN      93071                93071  244973287949
# 6                SGP     208349               208349  230099848496
# 7                IDN      35819                35819  162933845447
# 8                MYS      64880                64880  161741895330
# 9                SAU        602                  602  158896912371
#
#    measure_mean
# 0  1.105116e+06
# 1  8.643136e+05
# 2  1.393112e+06
# 3  2.380869e+06
# 4  2.902726e+06
# 5  2.632112e+06
# 6  1.104396e+06
# 7  4.548811e+06
# 8  2.492939e+06
# 9  2.639484e+08

# %%
print("Number of rows in top10:", len(top10))
print("Top 10 total measure:", top10["measure_sum"].sum())
# Out:
# Number of rows in top10: 10
# Top 10 total measure: 2725281293810

# %%
top10.to_csv(
    CONFIG["output_dir"] / "top10.csv",
    index=False,
)

print("top10.csv saved.")
# Out:
# top10.csv saved.

# %%
numpy_results = run_numpy_comparison(data)

numpy_results
# Out:
#              method        result  median_time_seconds
# 0       Python loop  1.627477e+10             0.002036
# 1  NumPy vectorized  1.627477e+10             0.000072

# %%
print("Loop and vectorized results agree:", numpy_results.attrs["numpy_equal"])
# Out:
# Loop and vectorized results agree: True

# %%
numpy_results.to_csv(
    CONFIG["output_dir"] / "numpy_comparison.csv",
    index=False,
)

print("numpy_comparison.csv saved.")
# Out:
# numpy_comparison.csv saved.

# %%
create_bar_plot(
    top10,
    CONFIG["output_dir"] / "bar.png",
)

print("bar.png created.")
# Out:
# bar.png created.

# %%
create_heatmap(
    pivot,
    CONFIG["output_dir"] / "heatmap.png",
)

print("heatmap.png created.")
# Out:
# heatmap.png created.

# %%
actual_sha256 = calculate_file_sha256(CONFIG["input_path"])

validation = create_validation_results(
    raw_stats=raw_stats,
    selected_data=data,
    grouped=grouped,
    grouped_two=grouped_two,
    pivot=pivot,
    numpy_equal=numpy_results.attrs["numpy_equal"],
    actual_sha256=actual_sha256,
)

validation
# Out:
#                        check  \
# 0              raw_row_count
# 1   raw_dutiablevaluephp_sum
# 2   missing_dutiablevaluephp
# 3         raw_rows_partition
# 4         selected_row_count
# 5       selected_measure_sum
# 6         grouped_row_counts
# 7                grouped_sum
# 8            grouped_two_sum
# 9         pivot_interior_sum
# 10         top10_plot_values
# 11       heatmap_plot_values
# 12     numpy_loop_vectorized
# 13           raw_file_sha256
#
#                                              expected  \
# 0                                             2236612
# 1                                       3587267375257
# 2                                                   0
# 3                                             2236612
# 4                                             2236612
# 5                                     3587267375257.0
# 6                                             2236612
# 7                                     3587267375257.0
# 8                                     3587267375257.0
# 9                                     3587267375257.0
# 10                                    2725281293810.0
# 11                                    3587267375257.0
# 12                                               True
# 13  b3b5a3a95340179a716a05611d51ad4906484d38363d1a...
#
#                                                actual  tolerance  pass
# 0                                             2236612        0.0  True
# 1                                     3587267375257.0        1.0  True
# 2                                                   0        0.0  True
# 3                                             2236612        0.0  True
# 4                                             2236612        0.0  True
# 5                                     3587267375257.0        1.0  True
# 6                                             2236612        0.0  True
# 7                                     3587267375257.0        1.0  True
# 8                                     3587267375257.0        1.0  True
# 9                                     3587267375257.0        1.0  True
# 10                                    2725281293810.0        1.0  True
# 11                                    3587267375257.0        1.0  True
# 12                                               True        0.0  True
# 13  b3b5a3a95340179a716a05611d51ad4906484d38363d1a...        0.0  True

# %%
print("All checks passed:", validation["pass"].all())
# Out:
# All checks passed: True

# %%
validation.to_csv(
    CONFIG["output_dir"] / "validation.csv",
    index=False,
)

print("validation.csv saved.")
# Out:
# validation.csv saved.

# %%
audit_log = pd.DataFrame(analyzer.audit_records)

audit_log
# Out:
#        step                    operation  \
# 0    filter   Apply two-condition filter
# 1    filter   Apply two-condition filter
# 2    filter   Apply two-condition filter
# 3    filter   Apply two-condition filter
# 4    filter   Apply two-condition filter
# 5    filter   Apply two-condition filter
# 6    filter   Apply two-condition filter
# 7    filter   Apply two-condition filter
# 8    filter   Apply two-condition filter
# 9    filter   Apply two-condition filter
# 10   filter   Apply two-condition filter
# 11   filter   Apply two-condition filter
# 12   filter   Apply two-condition filter
# 13   filter   Apply two-condition filter
# 14   filter   Apply two-condition filter
# 15   filter   Apply two-condition filter
# 16   filter   Apply two-condition filter
# 17   filter   Apply two-condition filter
# 18   filter   Apply two-condition filter
# 19   filter   Apply two-condition filter
# 20   filter   Apply two-condition filter
# 21   filter   Apply two-condition filter
# 22   filter   Apply two-condition filter
# 23  combine     Combine processed chunks
# 24  summary       Create grouped summary
# 25  summary  Create two-category summary
# 26  summary           Create pivot table
# 27  summary        Create top-10 summary
#
#                                           rule  rows_before  rows_after
# 0   tq is not missing AND dutiablevaluephp > 0       100000      100000
# 1   tq is not missing AND dutiablevaluephp > 0       100000      100000
# 2   tq is not missing AND dutiablevaluephp > 0       100000      100000
# 3   tq is not missing AND dutiablevaluephp > 0       100000      100000
# 4   tq is not missing AND dutiablevaluephp > 0       100000      100000
# 5   tq is not missing AND dutiablevaluephp > 0       100000      100000
# 6   tq is not missing AND dutiablevaluephp > 0       100000      100000
# 7   tq is not missing AND dutiablevaluephp > 0       100000      100000
# 8   tq is not missing AND dutiablevaluephp > 0       100000      100000
# 9   tq is not missing AND dutiablevaluephp > 0       100000      100000
# 10  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 11  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 12  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 13  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 14  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 15  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 16  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 17  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 18  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 19  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 20  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 21  tq is not missing AND dutiablevaluephp > 0       100000      100000
# 22  tq is not missing AND dutiablevaluephp > 0        36612       36612
# 23             Concatenate all filtered chunks      2236612     2236612
# 24                  Group by country of origin      2236612         197
# 25      Group by country of origin and quarter      2236612         628
# 26       Country by quarter with total margins          628         198
# 27      Keep ten largest groups by measure sum          197          10

# %%
audit_log.to_csv(
    CONFIG["output_dir"] / "audit_log.csv",
    index=False,
)

print("audit_log.csv saved.")
# Out:
# audit_log.csv saved.
